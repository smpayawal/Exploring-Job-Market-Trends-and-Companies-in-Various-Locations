# %% [markdown]
# ## Data Collection
# - Scrape job postings data from jobstreet (PH)
# - Include columns such as "Job Name", "Company Name", "Location", "Date Posted", "Job Specialization", "Job Type", and "Job Link"
# - Convert the "Date Posted" column from time data to date format using datetime library
# - Automate the web scraper to collect data up to the last available job postings and save it in a CSV file

# %%
import csv
import requests
from bs4 import BeautifulSoup

import re
import datetime
current_time = datetime.datetime.now()

# %%
# datetime conversation to date only
def convert_datetime(dt_posted):
    if dt_posted == 'now':
        return datetime.datetime.now().strftime("%Y-%m-%d")
    
    hours = 0
    minutes = 0
    days = 0
    
    match = re.match(r"(\d+)h ago", dt_posted)
    if match:
        hours = int(match.group(1))
    
    match = re.match(r"(\d+)m ago", dt_posted)
    if match:
        minutes = int(match.group(1))
    
    match = re.match(r"(\d+)d ago", dt_posted)
    if match:
        days = int(match.group(1))
    
    date = datetime.datetime.now() - datetime.timedelta(days=days, hours=hours, minutes=minutes)
    return date.strftime("%Y-%m-%d")

# %%
main_url = "https://www.jobstreet.com.ph/en/job-search/job-vacancy.php?pg={page}"
max_page = 1815 # maximum pages to scrape

# %%
# Create a new CSV file and write the headers as the first row
with open('jobs.csv', mode='w', newline='', encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(['Job Name', 'Company Name', 'Location', 'Date Posted', 'Job Specialization', 'Job Type', 'Job Link'])
    
    # Iterate over each page and extract the job information
    for page in range(1, max_page+1):
        url = main_url.format(page=page)
        response = requests.get(url)
        
        soup = BeautifulSoup(response.content, 'html.parser')
    
        for job in soup.find_all('div', class_='z1s6m00 _1hbhsw67i _1hbhsw66e _1hbhsw69q _1hbhsw68m _1hbhsw6n _1hbhsw65a _1hbhsw6ga _1hbhsw6fy'):
            try:
                job_name = job.find('div', class_='z1s6m00 l3gun70 l3gun74 l3gun72').get_text()
                company_name = job.find('span', class_='z1s6m00 _17dyj7u1 _1hbhsw64y _1hbhsw60 _1hbhsw6r').get_text()
                location = job.find('span', class_='z1s6m00 _1hbhsw64y y44q7i0 y44q7i3 y44q7i21 y44q7ih').get_text()
                date_posted = convert_datetime(job.find('span', class_='z1s6m00 _1hbhsw64y y44q7i0 y44q7i1 y44q7i22 y44q7ih').get_text())
                
                ddt = soup.find_all("div", class_="z1s6m00 _1hbhsw66u _1hbhsw67y _1hbhsw69q _1hbhsw68m rqoqz2")
                job_specialization = ddt.find("dt", text="Job Specializations").find_next_sibling("dd").text.strip()
                job_type = ddt.find("dt", text="Job Type").find_next_sibling("dd").text.strip()
                
                job_link = "https://www.jobstreet.com.ph" + job.find('a', class_ = 'jdlu994 jdlu996 jdlu999 y44q7i2 z1s6m00 z1s6m0f _1hbhsw6h')['href']

                # Write the extracted information to the CSV file
                writer.writerow([job_name, company_name, location, date_posted, job_specialization, job_type, job_link])
            except Exception as e:
                print(f"Failed to extract job information: {e}")
# Out:
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
# Failed to extract job information: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
url = 'https://www.jobstreet.com.ph/en/job-search/job-vacancy.php'

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

for job in soup.find_all('div', class_='z1s6m00 _1hbhsw69y _1hbhsw68u _1hbhsw67e _1hbhsw67q'):
    print(job.find('div', class_='z1s6m00 l3gun70 l3gun74 l3gun72').text.strip())
    print(job.find('span', class_='z1s6m00 _17dyj7u1 _1hbhsw64y _1hbhsw60 _1hbhsw6r').text.strip())
    print(job.find('span', class_='z1s6m00 _1hbhsw64y y44q7i0 y44q7i3 y44q7i21 y44q7
# Administrative AssistantGoCartQuezon CityOne of the largest multi-format retailers in the PhilippinesA strategic position which can influence the direction of the BUOpportunities for enhanced learning15h agoJob SpecializationsAdmin/Human Resources / Clerical/Administrative SupportJob TypeFull-Time
# ----
# Treasury Assistant (Open for Fresh Graduates)NORDE INTERNATIONAL DISTRIBUTORSQuezon City10h agoJob SpecializationsAccounting/Finance / Corporate Finance/InvestmentJob TypeContract
# ----
# Branch Personnel | La UnionPJ Lhuillier Group of CompaniesLa Union (Others), La Union (San Fernando)1d agoJob SpecializationsAccounting/Finance / Banking/FinancialJob TypeFull-Time
# ----
# Data Encoder / AnalystBusiness Process Resource Phils Inc.Negros Occidental (Bacolod)₱12K - 14,000 monthly9h agoJob SpecializationsAdmin/Human Resources / Clerical/Administrative SupportJob TypeFull-Time
# ----
# No Experience Needed | Fresh Graduates | Call Center Associate | TaguigCitigroup Business Process Solutions Pte. Ltd.National Capital Reg₱26K - 33,000 monthlyOver-the-Phone ProcessingCompetitive Salary Package and BenefitsRetirement Plan, HMO and Life Insurance4h agoJob SpecializationsServices / Customer ServiceJob TypeFull-Time
# ----
# No Experience Needed | Fresh Graduates | Customer Service Associate |Earn 26-33kCitigroup Business Process Solutions Pte. Ltd.National Capital Reg₱26K - 33,000 monthlyOver-the-Phone ProcessingCompetitive Salary Package and BenefitsRetirement Plan, HMO and Life Insurance4h agoJob SpecializationsServices / Customer ServiceJob TypeFull-Time
# ----
# No Experience Needed | Fresh Graduates | Customer Service Agent | TaguigCitigroup Business Process Solutions Pte. Ltd.National Capital Reg₱26K - 33,000 monthlyOver-the-Phone ProcessingCompetitive Salary Package and BenefitsRetirement Plan, HMO and Life Insurance5h agoJob SpecializationsServices / Customer ServiceJob TypeFull-Time
# ----
# No Experience Needed | Fresh Graduates | Customer Service Representative |BGCCitigroup Business Process Solutions Pte. Ltd.National Capital Reg₱26K - 33,000 monthlyOver-the-Phone ProcessingCompetitive Salary Package and BenefitsRetirement Plan, HMO and Life Insurance4h agoJob SpecializationsServices / Customer ServiceJob TypeFull-Time
# ----
# No Experience Needed | Fresh Graduates | Customer Service Representative |TaguigCitigroup Business Process Solutions Pte. Ltd.National Capital Reg₱26K - 33,000 monthlyOver-the-Phone ProcessingCompetitive Salary Package and BenefitsRetirement Plan, HMO and Life Insurance4h agoJob SpecializationsServices / Customer ServiceJob TypeFull-Time
# ----
# No Experience Needed | Fresh Graduates | Customer Service Agent | BGCCitigroup Business Process Solutions Pte. Ltd.National Capital Reg₱26K - 33,000 monthlyOver-the-Phone ProcessingCompetitive Salary Package and BenefitsRetirement Plan, HMO and Life Insurance4h agoJob SpecializationsServices / Customer ServiceJob TypeFull-Time
# ----
# No Experience Needed | Fresh Graduates | Customer Service Executive | BGCCitigroup Business Process Solutions Pte. Ltd.National Capital Reg₱26K - 33,000 monthlyOver-the-Phone ProcessingCompetitive Salary Package and BenefitsRetirement Plan, HMO and Life Insurance4h agoJob SpecializationsServices / Customer ServiceJob TypeFull-Time
# ----
# URGENT HIRING: ACCOUNT ASSOCIATE - CORPORATE BANKING (BGC Taguig)East West Banking CorporationNational Capital RegGuaranteed bonusesOpportunities for enhanced learningStart as soon as possible6h agoJob SpecializationsAccounting/Finance / Banking/FinancialJob TypeFull-Time
# ----

# %%
url = 'https://www.jobstreet.com.ph/en/job-search/job-vacancy.php'

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

for job in soup.find('div', {'class':'z1s6m00', 'data-automation': 'jobListing'}):
    jn = job.find_all('h1', class_='z1s6m00 _1hbhsw64y y44q7i0 y44q7i3 y44q7i21 y44q7ii')
    text = [j.get_text() for j in jn]
    print(text)
    
    cn = job.find_all('a', {'class': '_6xa4xb0 z1s6m00 z1s6m0f rqoqz4', 'data-automation': 'jobCardCompanyLink'})
    #cn = job.find_all('span', class_='z1s6m00 _17dyj7u1 _1hbhsw64y _1hbhsw60 _1hbhsw6r')
    ttext = [c.get_text() for c in cn]
    print(ttext)
    
    loc = job.find_all('a', {'class': '_6xa4xb0 z1s6m00 z1s6m0f rqoqz4', 'data-automation':'jobCardLocationLink'})
    tttext = [l.get_text() for l in loc]
    print(tttext)
    
    print('----')
# Out:
# ['Admin Assistant']
# ['F1RST ONE EDUCATION MIGRATION LEARNING HUB']
# ['Taguig City']
# ----
# ['IT ADMINISTRATOR']
# ['Nobile Inc.']
# ['Caloocan City']
# ----
# ['OFFICE ASSISTANT']
# ['Iridium Technologies, Inc.']
# ['National Capital Reg']
# ----
# ['OFFICE STAFF']
# []
# ['National Capital Reg']
# ----
# ['No Experience Needed | Fresh Graduates | Customer Service Support | BGC']
# ['Citigroup Business Process Solutions Pte. Ltd.']
# ['National Capital Reg']
# ----
# ['No Experience Needed | Fresh Graduates | Customer Service Support |Earn 26k-33k']
# ['Citigroup Business Process Solutions Pte. Ltd.']
# ['National Capital Reg']
# ----
# ['Reservation Associate']
# ['City Garden Hotel Makati']
# ['National Capital Reg']
# ----
# ['BANK TELLER - Davao and Zamboanga']
# ['Philippine National Bank (PNB)']
# ['Davao del Sur (Davao City)', 'Zamboanga']
# ----
# ['NON-VOICE/Voice Agent (BACK OFFICE) | No Work Experience Required (Up to 29k* PAY) - Makati']
# ['Foundever™']
# ['National Capital Reg']
# ----
# ['Customer Service Representative']
# ['Royal Cargo Inc.']
# ['Paranaque City']
# ----
# ['NON-VOICE (Email/Voice) Support - 22k* PAY! | No Exp Needed (Shaw) - APPLY NOW, MASS HIRING!']
# ['Foundever™']
# ['Mandaluyong City']
# ----
# ['No Experience Needed | Fresh Graduates | Customer Service Associate | BGC']
# ['Citigroup Business Process Solutions Pte. Ltd.']
# ['National Capital Reg']
# ----
# ['No Experience Needed | Fresh Graduates | Customer Service Support | Taguig']
# ['Citigroup Business Process Solutions Pte. Ltd.']
# ['National Capital Reg']
# ----
# ['Start ASAP! DATA ENCODER - No Data Entry Exp Needed (Email/Voice) | Shaw Urgent Hiring!']
# ['Foundever™']
# ['National Capital Reg']
# ----
# ['DATA ENCODER - No Data Entry Experience Required! (Back Office Account) | Email/Voice Support - Shaw']
# ['Foundever™']
# ['National Capital Reg']
# ----
# ['OFFICE STAFF']
# ['Marcbilt Contruction Inc.']
# ['Muntinlupa City']
# ----
# ['Administrative Clerk']
# ['Royal Bear Confectioneries Inc.']
# ['National Capital Reg']
# ----
# ['Operations Management Trainee - Western Visayas']
# ['Philippine Seven Corporation']
# ['Iloilo (Iloilo City)', 'Iloilo (Others)', 'Capiz', 'Aklan']
# ----
# ['Administrative Assistant']
# ['GoCart']
# ['Quezon City']
# ----
# ['Treasury Assistant (Open for Fresh Graduates)']
# ['NORDE INTERNATIONAL DISTRIBUTORS']
# ['Quezon City']
# ----
# ['Branch Personnel | La Union']
# ['PJ Lhuillier Group of Companies']
# ['La Union (Others)', 'La Union (San Fernando)']
# ----
# ['Data Encoder / Analyst']
# ['Business Process Resource Phils Inc.']
# ['Negros Occidental (Bacolod)']
# ----
# ['No Experience Needed | Fresh Graduates | Call Center Associate | Taguig']
# ['Citigroup Business Process Solutions Pte. Ltd.']
# ['National Capital Reg']
# ----
# ['No Experience Needed | Fresh Graduates | Customer Service Associate |Earn 26-33k']
# ['Citigroup Business Process Solutions Pte. Ltd.']
# ['National Capital Reg']
# ----
# ['No Experience Needed | Fresh Graduates | Customer Service Representative |BGC']
# ['Citigroup Business Process Solutions Pte. Ltd.']
# ['National Capital Reg']
# ----
# ['No Experience Needed | Fresh Graduates | Customer Service Agent | BGC']
# ['Citigroup Business Process Solutions Pte. Ltd.']
# ['National Capital Reg']
# ----
# ['No Experience Needed | Fresh Graduates | Customer Service Agent | Taguig']
# ['Citigroup Business Process Solutions Pte. Ltd.']
# ['National Capital Reg']
# ----
# ['No Experience Needed | Fresh Graduates | Customer Service Representative |Taguig']
# ['Citigroup Business Process Solutions Pte. Ltd.']
# ['National Capital Reg']
# ----
# ['No Experience Needed | Fresh Graduates | Customer Service Executive | BGC']
# ['Citigroup Business Process Solutions Pte. Ltd.']
# ['National Capital Reg']
# ----
# ['URGENT HIRING: ACCOUNT ASSOCIATE - CORPORATE BANKING (BGC Taguig)']
# ['East West Banking Corporation']
# ['National Capital Reg']
# ----

# %%
url = 'https://www.jobstreet.com.ph/en/job-search/job-vacancy.php'

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

for job in soup.find('div', {'class':'z1s6m00', 'data-automation': 'jobListing'}):
    job_name = job.find('h1', class_='z1s6m00 _1hbhsw64y y44q7i0 y44q7i3 y44q7i21 y44q7ii').get_text()
    print(job_name)
    
    company_name = job.find('a', {'class': '_6xa4xb0 z1s6m00 z1s6m0f rqoqz4', 'data-automation': 'jobCardCompanyLink'})
    if company_name is None:
        company_name = "Confidential"
        print(company_name)
    else:
        print(company_name.get_text())
    
    location = job.find('a', {'class': '_6xa4xb0 z1s6m00 z1s6m0f rqoqz4', 'data-automation':'jobCardLocationLink'}).get_text()
    print(location)
    
    date_posted = convert_datetime(job.find('span', class_='z1s6m00 _1hbhsw64y y44q7i0 y44q7i1 y44q7i22 y44q7ih').text.strip())
    print(date_posted)
    
    job_link = "https://www.jobstreet.com.ph" + job.find('a', class_ = 'jdlu994 jdlu996 jdlu999 y44q7i2 z1s6m00 z1s6m0f _1hbhsw6h')['href']
    print(job_link)
    
    job_specialization = job.find("dt", text="Job Specializations").find_next_sibling("dd").text.strip()
    
    print(job_specialization)
    
    job_type = job.find("dt", text="Job Type").find_next_sibling("dd").text.strip()
    print(job_type)
    
    print('----')
# Out:
# Admin Assistant
# F1RST ONE EDUCATION MIGRATION LEARNING HUB
# Taguig City
# 2023-04-17
# https://www.jobstreet.com.ph/en/job
token=0~ed4579b3-e448-4b09-89d6-667a926ff5a5&fr=SRP%20Job%20Listing
# Services
# Full-Time
# ----
# Administrative Clerk
# Royal Bear Confectioneries Inc.
# National Capital Reg
# 2023-04-17
# https://www.jobstreet.com.ph/en/job/administrative-clerk-12952635?jobId=jobstreet-ph-job-12952635&sectionRank=16&token=0~ed4579b3-e448-4b09-89d6-667a926ff5a5&fr=SRP%20Job%20Listing
# Admin/Human Resources
# Full-Time
# ----
# OFFICE STAFF
# Marcbilt Contruction Inc.
# Muntinlupa City
# 2023-04-17
# https://www.jobstreet.com.ph/en/job/office-staff-12951999?jobId=jobstreet-ph-job-12951999&sectionRank=17&token=0~ed4579b3-e448-4b09-89d6-667a926ff5a5&fr=SRP%20Job%20Listing
# Admin/Human Resources
# Full-Time
# ----
# Operations Management Trainee - Western Visayas
# Philippine Seven Corporation
# Iloilo (Iloilo City)
# 2023-04-17
# https://www.jobstreet.com.ph/en/job/operations-management-trainee-western-visayas-12951233?jobId=jobstreet-ph-job-12951233&sectionRank=18&token=0~ed4579b3-e448-4b09-89d6-667a926ff5a5&fr=SRP%20Job%20Listing
# Engineering
# Full-Time
# ----
# Administrative Assistant
# GoCart
# Quezon City
# 2023-04-17
# https://www.jobstreet.com.ph/en/job/administrative-assistant-12922966?jobId=jobstreet-ph-job-12922966&sectionRank=19&token=0~ed4579b3-e448-4b09-89d6-667a926ff5a5&fr=SRP%20Job%20Listing
# Admin/Human Resources
# Full-Time
# ----
# Treasury Assistant (Open for Fresh Graduates)
# NORDE INTERNATIONAL DISTRIBUTORS
# Quezon City
# 2023-04-17
# https://www.jobstreet.com.ph/en/job/treasury-assistant-open-for-fresh-graduates-12951483?jobId=jobstreet-ph-job-12951483&sectionRank=20&token=0~ed4579b3-e448-4b09-89d6-667a926ff5a5&fr=SRP%20Job%20Listing
# Accounting/Finance
# Contract
# ----
# Data Encoder / Analyst
# Business Process Resource Phils Inc.
# Negros Occidental (Bacolod)
# 2023-04-17
# https://www.jobstreet.com.ph/en/job/data-encoder-analyst-12951620?jobId=jobstreet-ph-job-12951620&sectionRank=21&token=0~ed4579b3-e448-4b09-89d6-667a926ff5a5&fr=SRP%20Job%20Listing
# Admin/Human Resources
# Full-Time
# ----
# No Experience Needed | Fresh Graduates | Call Center Associate | Taguig
# Citigroup Business Process Solutions Pte. Ltd.
# National Capital Reg
# 2023-04-17
# https://www.jobstreet.com.ph/en/job/no-experience-needed-%7C-fresh-graduates-%7C-call-center-associate-%7C-taguig-12953241?jobId=jobstreet-ph-job-12953241&sectionRank=22&token=0~ed4579b3-e448-4b09-89d6-667a926ff5a5&fr=SRP%20Job%20Listing
# Services
# Full-Time
# ----
# No Experience Needed | Fresh Graduates | Customer Service Associate |Earn 26-33k
# Citigroup Business Process Solutions Pte. Ltd.
# National Capital Reg
# 2023-04-17
# https://www.jobstreet.com.ph/en/job/no-experience-needed-%7C-fresh-graduates-%7C-customer-service-associate-%7Cearn-26-33k-12953290?jobId=jobstreet-ph-job-12953290&sectionRank=23&token=0~ed4579b3-e448-4b09-89d6-667a926ff5a5&fr=SRP%20Job%20Listing
# Services
# Full-Time
# ----
# No Experience Needed | Fresh Graduates | Customer Service Representative |BGC
# Citigroup Business Process Solutions Pte. Ltd.
# National Capital Reg
# 2023-04-17
# https://www.jobstreet.com.ph/en/job/no-experience-needed-%7C-fresh-graduates-%7C-customer-service-representative-%7Cbgc-12953220?jobId=jobstreet-ph-job-12953220&sectionRank=24&token=0~ed4579b3-e448-4b09-89d6-667a926ff5a5&fr=SRP%20Job%20Listing
# Services
# Full-Time
# ----
# No Experience Needed | Fresh Graduates | Customer Service Agent | Taguig
# Citigroup Business Process Solutions Pte. Ltd.
# National Capital Reg
# 2023-04-17
# https://www.jobstreet.com.ph/en/job/no-experience-needed-%7C-fresh-graduates-%7C-customer-service-agent-%7C-taguig-12953072?jobId=jobstreet-ph-job-12953072&sectionRank=25&token=0~ed4579b3-e448-4b09-89d6-667a926ff5a5&fr=SRP%20Job%20Listing
# Services
# Full-Time
# ----
# No Experience Needed | Fresh Graduates | Customer Service Representative |Taguig
# Citigroup Business Process Solutions Pte. Ltd.
# National Capital Reg
# 2023-04-17
# https://www.jobstreet.com.ph/en/job/no-experience-needed-%7C-fresh-graduates-%7C-customer-service-representative-%7Ctaguig-12953099?jobId=jobstreet-ph-job-12953099&sectionRank=26&token=0~ed4579b3-e448-4b09-89d6-667a926ff5a5&fr=SRP%20Job%20Listing
# Services
# Full-Time
# ----
# No Experience Needed | Fresh Graduates | Customer Service Agent | BGC
# Citigroup Business Process Solutions Pte. Ltd.
# National Capital Reg
# 2023-04-17
# https://www.jobstreet.com.ph/en/job/no-experience-needed-%7C-fresh-graduates-%7C-customer-service-agent-%7C-bgc-12953180?jobId=jobstreet-ph-job-12953180&sectionRank=27&token=0~ed4579b3-e448-4b09-89d6-667a926ff5a5&fr=SRP%20Job%20Listing
# Services
# Full-Time
# ----
# No Experience Needed | Fresh Graduates | Customer Service Executive | BGC
# Citigroup Business Process Solutions Pte. Ltd.
# National Capital Reg
# 2023-04-17
# https://www.jobstreet.com.ph/en/job/no-experience-needed-%7C-fresh-graduates-%7C-customer-service-executive-%7C-bgc-12953200?jobId=jobstreet-ph-job-12953200&sectionRank=28&token=0~ed4579b3-e448-4b09-89d6-667a926ff5a5&fr=SRP%20Job%20Listing
# Services
# Full-Time
# ----
# URGENT HIRING: ACCOUNT ASSOCIATE - CORPORATE BANKING (BGC Taguig)
# East West Banking Corporation
# National Capital Reg
# 2023-04-17
# https://www.jobstreet.com.ph/en/job/urgent-hiring%3A-account-associate-corporate-banking-bgc-taguig-12952499?jobId=jobstreet-ph-job-12952499&sectionRank=29&token=0~ed4579b3-e448-4b09-89d6-667a926ff5a5&fr=SRP%20Job%20Listing
# Accounting/Finance
# Full-Time
# ----
# No Experience Needed | Fresh Graduates | Customer Service Professional | BGC
# Citigroup Business Process Solutions Pte. Ltd.
# National Capital Reg
# 2023-04-17
# https://www.jobstreet.com.ph/en/job/no-experience-needed-%7C-fresh-graduates-%7C-customer-service-professional-%7C-bgc-12953209?jobId=jobstreet-ph-job-12953209&sectionRank=30&token=0~ed4579b3-e448-4b09-89d6-667a926ff5a5&fr=SRP%20Job%20Listing
# Services
# Full-Time
# ----
# C:\Users\Tien Tien\AppData\Local\Temp\ipykernel_4604\525140111.py:26: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   job_specialization = job.find("dt", text="Job Specializations").find_next_sibling("dd").text.strip()
# C:\Users\Tien Tien\AppData\Local\Temp\ipykernel_4604\525140111.py:30: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   job_type = job.find("dt", text="Job Type").find_next_sibling("dd").text.strip()
